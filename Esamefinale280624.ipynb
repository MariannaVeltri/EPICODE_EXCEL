# %%
import pandas as pd

# %%
covid19=pd.read_csv("owid-covid-data.csv")

# %% [markdown]
# Si richiede di verificare le dimensioni del dataset e i relativi metadati;

# %%
len(covid19)
# Out:
# 409562

# %%
covid19.shape
# Out:
# (409562, 67)

# %%
covid19.sample(5)
# Out:
#         iso_code      continent     location        date  total_cases  \
# 158860       HND  North America     Honduras  2023-11-11     472743.0
# 270986       NOR         Europe       Norway  2020-07-02       8858.0
# 254808       NZL        Oceania  New Zealand  2021-12-11      11959.0
# 403802  OWID_WRL            NaN        World  2022-01-24  351884035.0
# 112866       ETH         Africa     Ethiopia  2022-08-13     492476.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 158860        0.0               0.000       11114.0         0.0
# 270986        0.0              16.429         249.0         0.0
# 254808        0.0             126.857          44.0         0.0
# 403802        0.0         3363087.714     5647301.0         0.0
# 112866        0.0              40.286        7569.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 158860                0.000  ...           NaN                  84.169
# ...

# %%
covid19.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# Si chiede poi per ogni continente di trovare il numero di casi totali
# avvenuti in quello stesso continente;
# si chiede di non considerare eventuali locazioni che nel dataset non
# appartengono ad alcun continente;

# %%
import pandas as pd

#carica il file csv
df=pd.read_csv("owid-covid-data.csv")

#filtra le righe dove il campo 'continent' non è NaN
df_filtered=df.dropna(subset=['continent'])

grouped_df= df_filtered.groupby('continent')['total_cases'].sum()

#mostra i risultati
print(grouped_df)
# Out:
# continent
# Africa           1.397275e+10
# Asia             2.373950e+11
# Europe           2.243707e+11
# North America    1.210058e+11
# Oceania          1.086353e+10
# South America    7.012202e+10
# Name: total_cases, dtype: float64

# %% [markdown]
# Sempre riguardo i casi totali, si chiede di scrivere del codice che,
# date due variabili contenenti i nomi di continenti,
# ne confronti i seguenti relativi descrittori statistici: valore massimo,
# media, e percentuale rispetto al numero dei casi totali nel mondo
# (calcolati anche sulle locazioni senza indicazione di continente);

# %%
import pandas as pd

#carica il file csv
df=pd.read_csv("owid-covid-data.csv")

#filtra le righe dove il campo 'continent' non è NaN
df_filteredt=df.dropna(subset=['continent'])

grouped_df=df_filtered.groupby('continent')['total_cases'].max()

print(grouped_df)
# Out:
# continent
# Africa             4072719.0
# Asia              99361338.0
# Europe            38997490.0
# North America    103436829.0
# Oceania           11861161.0
# South America     37511921.0
# Name: total_cases, dtype: float64

# %%
import pandas as pd

#carica il file csv
df=pd.read_csv("owid-covid-data.csv")

#filtra le righe dove il campo 'continent' non è NaN
df_filteredt=df.dropna(subset=['continent'])

grouped_df=df_filtered.groupby('continent')['total_cases'].mean()

print(grouped_df)
# Out:
# continent
# Africa           1.598402e+05
# Asia             3.388162e+06
# Europe           2.801517e+06
# North America    1.900067e+06
# Oceania          3.853409e+05
# South America    3.214837e+06
# Name: total_cases, dtype: float64

# %%
import pandas as pd

#carica il file csv
df=pd.read_csv("owid-covid-data.csv")

#filtra le righe dove il campo 'continent' non è NaN
df_filteredt=df.dropna(subset=['continent'])

total_cases_global= df_filtered['total_cases'].sum()
grouped_df=df_filtered.groupby('continent')['total_cases'].sum().reset_index()

grouped_df['percentuale']= (grouped_df['total_cases']/total_cases_global)*100

print(grouped_df)
# Out:
#        continent   total_cases  percentuale
# 0         Africa  1.397275e+10     2.061700
# 1           Asia  2.373950e+11    35.027972
# 2         Europe  2.243707e+11    33.106220
# 3  North America  1.210058e+11    17.854574
# 4        Oceania  1.086353e+10     1.602930
# 5  South America  7.012202e+10    10.346605

# %% [markdown]
# Selezionare i dati relativi all'Italia nel 2022, e mostrare con un
# grafico adeguato l'evoluzione del casi totali rispetto alla data.
# Mostrare poi con un grafico adeguato il numero di nuovi casi rispetto
# alla data (filtrare i dati se necessario). Mostrare infine un grafico
# che mostra l'andamento della somma cumulativa nuovi casi del 2022, e
# commentare se ci sono similarità con l'andamento del numero dei casi
# totali;

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

df = pd.read_csv('owid-covid-data.csv')

df['date'] =pd.to_datetime(df['date']) #converti la colonna 'date' in datatime
filtered_df = df[(df['location'] == 'Italy') & (df['date'].dt.year == 2022)]

x_value = filtered_df['total_cases']
y_value = filtered_df['date']

plt.plot(x_value,y_value)
plt.xlabel ('Anno di riferimento 2022')
plt.ylabel('Casi totali in Italia')
plt.title('Evoluzione dei casi totali nell\'anno 2022')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

df = pd.read_csv('owid-covid-data.csv')

#df['date'] =pd.to_datetime(df['date']) #converti la colonna 'date' in datatime
#filtered_df = df[(df['new_cases'] == 'Casi') & (df['date'].dt.year == 2022)]

x_value = filtered_df['new_cases']
y_value = filtered_df['date']

plt.plot(x_value,y_value)
plt.xlabel ('Nuovi casi Totali')
plt.ylabel('Anno di riferimento 2022')
plt.title('Nuovi casi nel 2022')
plt.show()

print(len(filtered_df))
# Out:
# 365

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

df = pd.read_csv('owid-covid-data.csv')

df['date'] = pd.to_datetime(df['date']) #converti la colonna 'date' in datatime
filtered_df = df[df['date'].dt.year == 2022]

grouped_df= filtered_df.groupby('date')['new_cases'].sum().reset_index()

x_value = grouped_df['date']
y_value = grouped_df['new_cases']

plt.plot(x_value,y_value)
plt.xlabel ('anno')
plt.ylabel('nuovi casi')
plt.title('somma nuovi casi per anno')
plt.show()

# %% [markdown]
# Riguardo le nazioni Italia, Germania,Francia e Spagna nel 2023, mostrare la somma dei pazienti ospitalizzati per ognuna, se ci sono casi nulli, sugerire se può essere possibile gestirli tramite sostituzione o meno.

# %%
import pandas as pd
from datetime import datetime

df=pd.read_csv("owid-covid-data.csv")

df['date'] = pd.to_datetime(df['date'])
filtered_df = df[df['date'].dt.year == 2023]
nation = ['Italy','Germany','France','Spain']
location_df = filtered_df[filtered_df['location'].isin(nation)] 

grouped_df = location_df.groupby('location')['hosp_patients'].sum()

print(grouped_df)
# Out:
# location
# France     1382574.0
# Germany          0.0
# Italy      1175272.0
# Spain       354602.0
# Name: hosp_patients, dtype: float64
